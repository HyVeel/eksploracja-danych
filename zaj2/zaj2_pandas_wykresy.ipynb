# %% [markdown]
# <a href="https://colab.research.google.com/github/HyVeel/eksploracja-danych/blob/main/zaj2/zaj2_pandas_wykresy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random

from IPython.display import display, HTML

plt.rcParams.update({'font.size': 15})

# %% [markdown]
# # **Pandas i wykresy**

# %%
data = {
    "state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada", "Nevada"],
    "year": [2000, 2001, 2002, 2001, 2002, 2003],
    "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]
}

# Tworzenie DataFrame
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
display(HTML(frame.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>year</th>
#       <th>pop</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Ohio</td>
#       <td>2000</td>
#       <td>1.5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Ohio</td>
#       <td>2001</td>
#       <td>1.7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Ohio</td>
#       <td>2002</td>
#       <td>3.6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Nevada</td>
#       <td>2001</td>
#       <td>2.4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Nevada</td>
#       <td>2002</td>
#       <td>2.9</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Nevada</td>
#       <td>2003</td>
#       <td>3.2</td>
#     </tr>
#   </tbody>
# </table>

# %%
frame.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
frame.tail()
# Out:
#     state  year  pop
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
# Zamiana kolejności kolumn
pd.DataFrame(data, columns=["year", "state", "pop"])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
frame.loc[1]
# Out:
# state    Ohio
# year     2001
# pop       1.7
# Name: 1, dtype: object

# %%
frame.iloc[1]
# Out:
# state    Ohio
# year     2001
# pop       1.7
# Name: 1, dtype: object

# %%
frame['state']
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
frame['pop']
# Out:
# 0    1.5
# 1    1.7
# 2    3.6
# 3    2.4
# 4    2.9
# 5    3.2
# Name: pop, dtype: float64

# %%
frame[["state", "pop"]]
# Out:
#     state  pop
# 0    Ohio  1.5
# 1    Ohio  1.7
# 2    Ohio  3.6
# 3  Nevada  2.4
# 4  Nevada  2.9
# 5  Nevada  3.2

# %%
# Filtracja danych
ohio_data = frame[frame['state'] == 'Ohio']
nevada_data = frame[frame['state'] == 'Nevada']

# Tworzenie wykresu
plt.plot(ohio_data['year'], ohio_data['pop'], marker='o', linestyle='-', color='b',
        label="Ohio")
plt.plot(nevada_data['year'], nevada_data['pop'], marker='o', linestyle='-', color='r',
        label="Nevada")
plt.title('Rok vs Populacja dla Ohio i Nevady')
plt.xlabel('Rok')
plt.ylabel('Populacja [mln]')

# Ustawienie etykiet osi X, aby wyświetlały tylko konkretne lata
plt.xticks([2000, 2001, 2002, 2003])

plt.legend()

# %%
ohio_data.plot(x='year', y='pop', marker='o', linestyle='-', color='b', label="Ohio")
nevada_data.plot(x='year', y='pop', marker='o', linestyle='-', color='r', label="Nevada")
plt.title('Rok vs Populacja dla Ohio i Nevady')
plt.xlabel('Rok')
plt.ylabel('Populacja [mln]')

# Ustawienie etykiet osi X, aby wyświetlały tylko konkretne lata
plt.xticks([2000, 2001, 2002, 2003])

plt.legend()

# %%
# Tutaj wykres w sposób obiektowy

fig, ax = plt.subplots()
ohio_data.plot(x='year', y='pop', marker='o', linestyle='-', color='b', label="Ohio", ax=ax)
nevada_data.plot(x='year', y='pop', marker='o', linestyle='-', color='r', label="Nevada", ax=ax)
ax.set_title('Rok vs Populacja dla Ohio i Nevady')
ax.set_xlabel('Rok')
ax.set_ylabel('Populacja [mln]')

# Ustawienie etykiet osi X, aby wyświetlały tylko konkretne lata
ax.set_xticks([2000, 2001, 2002, 2003])

plt.legend()

# %%
# Filtracja danych
ohio_data = frame[(frame['state'] == 'Ohio') & (frame['year'].isin([2001, 2002]))]
nevada_data = frame[(frame['state'] == 'Nevada') & (frame['year'].isin([2001, 2002]))]

# Tworzenie wykresu
plt.plot(ohio_data['year'], ohio_data['pop'], marker='o', linestyle='-', color='b',
        label="Ohio")
plt.plot(nevada_data['year'], nevada_data['pop'], marker='o', linestyle='-', color='r',
        label="Nevada")
plt.title('Rok vs Populacja dla Ohio i Nevady')
plt.xlabel('Rok')
plt.ylabel('Populacja [mln]')

# Ustawienie etykiet osi X, aby wyświetlały tylko konkretne lata
plt.xticks([2001, 2002])
plt.ylim([1.5, 3.8])
plt.legend()

# %%
# Zapisywanie DataFrame do pliku CSV
frame.to_csv('pop_Ohio_Nevada.csv', index=False)

# %%
! pwd
# Out:
# /content

# %% [markdown]
# # **Zadanie dla chętnych**
#
# ## Cel
#
# Stworzenie wykresu słupkowego (bar plot) przedstawiającego populację stanów Ohio i Nevada w latach 2001 i 2002, używając danych z pliku CSV i języka Python.
#
# ## Dane
#
# Dane są przechowywane w pliku `pop_Ohio_Nevada.csv`, który zawiera trzy kolumny: `state`, `year` i `pop`.
#
# ## Instrukcje
#
# 1. Wczytaj dane do DataFrame z pliku `pop_Ohio_Nevada.csv`.
# 2. Przefiltruj dane, aby zawierały tylko informacje o stanie Ohio i Nevada dla lat 2001 i 2002.
# 3. Utwórz wykres słupkowy, na którym będą przedstawione dwie grupy słupków - jedna dla Ohio i druga dla Nevada. Każda grupa powinna zawierać słupki dla roku 2001 i 2002.
# 4. Dodaj etykiety do osi X i Y, tytuł wykresu oraz legendę.
#
#
# ![bar_plot_pop_US(1).png](data:image/png;base64,...)

# %%
df = pd.read_csv("pop_Ohio_Nevada.csv")

# %%
df
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
filtered_df = df[df["year"].isin([2001, 2002])]

# %%
filtered_df
# Out:
#     state  year  pop
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
ohio_data = filtered_df[filtered_df["state"] == "Ohio"]
nevada_data = filtered_df[filtered_df["state"] == "Nevada"]

years = ["2001", "2002"]
x = np.arange(len(years))
width = 0.3

plt.figure()
plt.bar(x - width / 2, ohio_data["pop"], width, label="Ohio")
plt.bar(x + width / 2, nevada_data["pop"], width, label="Nevada")
plt.xticks(x, years)
plt.xlabel("Rok")
plt.ylabel("Populacja [mln]")
plt.title("Populacja w Ohio i Nevadzie w latach 2001 i 2002")
plt.legend()
plt.show()

# %% [markdown]
# # **Zadanie na zajęcia**

# %% [markdown]
# ## Zadanie 1
#
# ### Cel:
# Stworzenie słownika z danymi populacyjnymi, przekształcenie go w DataFrame i eksport do pliku CSV.
#
# ### Dane:
# Liczba mieszkańców Warszawy i Łodzi w wybranych latach:
#
# | Rok   | Warszawa   | Łódź         |
# |-------|------------|--------------|
# | 2002  | 1 672 000  | 789 318      |
# | 2011  | 1 707 000  | 728 892      |
# | 2015  | 1 740 000  | Brak danych  |
# | 2022  | 1 795 000  | 670 642      |
#
# ### Polecenia:
#
# 1. Przekształć powyższą tabelę w słownik Pythona (kolumny jako klucze, dane jako listy wartości)
# 2. Utwórz DataFrame z biblioteki pandas na podstawie słownika
# 3. Zapisz DataFrame do pliku CSV o nazwie `populacja_miast.csv`

# %%
cities = {
    "Rok": [2002, 2011, 2015, 2022],
    "Warszawa": [1672000, 1707000, 1740000, 1795000],
    "Łódź": [789318, 728892, None, 670642]
}

# %%
df = pd.DataFrame(cities)

# %%
df.to_csv("populacja_miast.csv", index=False)

# %% [markdown]
# ## Zadanie 2
#
# ### Cel:
# Celem tego zadania jest wczytanie danych z pliku CSV, analiza i wizualizacja tych danych na wykresach liniowych.
#
# ### Zadania:
# 1. Wczytaj dane z pliku `populacja_miast.csv` do DataFrame przy użyciu biblioteki pandas.
# 2. Stwórz wykres liniowy, który pokaże, jak zmieniała się populacja Warszawy i Łodzi na przestrzeni lat.
# 3. Stwórz drugi wykres liniowy, który pokaże zmiany populacji tylko dla lat 2002, 2011 i 2022.

# %%
df_cities = pd.read_csv("populacja_miast.csv")
df_cities
# Out:
#     Rok  Warszawa      Łódź
# 0  2002   1672000  789318.0
# 1  2011   1707000  728892.0
# 2  2015   1740000       NaN
# 3  2022   1795000  670642.0

# %%
plt.plot(df_cities["Rok"], df_cities["Warszawa"], marker="o", label="Warszawa")
plt.plot(df_cities["Rok"], df_cities["Łódź"], marker="o", label="Łódź")
plt.title("Populacja Warszawy i Łodzi na przestrzeni lat")
plt.xlabel("Rok")
plt.ylabel("Populacja [mln]")
plt.grid(alpha=0.4)
plt.legend()
plt.show()

# %%
years = [2002, 2011, 2022]
df_cities_years = df_cities[df_cities["Rok"].isin(years)]

plt.plot(df_cities_years["Rok"], df_cities_years["Warszawa"], marker="o", label="Warszawa")
plt.plot(df_cities_years["Rok"], df_cities_years["Łódź"], marker="o", label="Łódź")
plt.xticks([2002, 2011, 2022])
plt.title("Populacja Warszawy i Łodzi na przestrzeni lat")
plt.xlabel("Rok")
plt.ylabel("Populacja [mln]")
plt.grid(alpha=0.4)
plt.legend()
plt.show()
